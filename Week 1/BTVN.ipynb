# %%
#1
def tron_hai_mang(a, b):
    ket_qua = []
    i = 0
    while i < len(a) and i < len(b):
        if a[i] < b[i]:
            ket_qua.append(a[i])
        else:
            ket_qua.append(b[i])
        i += 1

    if i < len(a):
        ket_qua.extend(a[i:])
    if i < len(b):
        ket_qua.extend(b[i:])

    return ket_qua

mang_a = [3, 9, 1, 4]
mang_b = [2, 7, 4, 3, 2, 8]
kq1 = tron_hai_mang(mang_a, mang_b)
print("Bài 1 - Mảng kết quả:", kq1)

# %%
#2
import numpy as np

# Định nghĩa các hàm xử lý ma trận
def giai_cau_2(a, n, x):
    print(f"--- Đang xử lý ma trận cấp {n}x{n} ---\n")

    # a. Tính tổng phần tử thuộc tam giác trên của đường chéo phụ (kể cả đường chéo phụ)
    # Quy luật: i + j <= n - 1
    tong_tg_phu = 0
    for i in range(n):
        for j in range(n - i):
            tong_tg_phu += a[i][j]
    print(f"a. Tổng tam giác trên chéo phụ: {tong_tg_phu}")

    # b. Chuyển các phần tử âm thành trị tuyệt đối
    for i in range(n):
        for j in range(n):
            if a[i][j] < 0:
                a[i][j] = abs(a[i][j])
    print(f"b. Ma trận sau khi lấy trị tuyệt đối: {a}")

    # c. Thay các phần tử chẵn bằng số nguyên x cho trước
    for i in range(n):
        for j in range(n):
            if a[i][j] % 2 == 0:
                a[i][j] = x
    print(f"c. Ma trận sau khi thay số chẵn bằng {x}: {a}")

    # d. Kiểm tra a có toàn chẵn không?
    toan_chan = True
    for i in range(n):
        for j in range(n):
            if a[i][j] % 2 != 0:
                toan_chan = False
                break
    print(f"d. Ma trận toàn chẵn: {toan_chan}")

    # e. Kiểm tra ma trận đối xứng (a[i][j] == a[j][i])
    doi_xung = True
    for i in range(n):
        for j in range(i + 1, n):
            if a[i][j] != a[j][i]:
                doi_xung = False
                break
    print(f"e. Ma trận đối xứng: {doi_xung}")

    # f. Kiểm tra đường chéo chính có tăng dần không
    cheo_chinh_tang = True
    for i in range(n - 1):
        if a[i][i] >= a[i+1][i+1]:
            cheo_chinh_tang = False
            break
    print(f"f. Đường chéo chính tăng dần: {cheo_chinh_tang}")

    # g. Xuất các phần tử thuộc tam giác dưới của đường chéo phụ (kể cả đường chéo phụ)
    # Quy luật: i + j >= n - 1
    print("g. Các phần tử thuộc tam giác dưới chéo phụ:")
    for i in range(n):
        for j in range(n - 1 - i, n):
            print(a[i][j], end=" ")
        print()

    # h. Kiểm tra đường chéo phụ có giảm dần không
    # Các phần tử chéo phụ: a[0][n-1], a[1][n-2], ..., a[n-1][0]
    cheo_phu_giam = True
    for i in range(n - 1):
        if a[i][n-1-i] <= a[i+1][n-1-(i+1)]:
            cheo_phu_giam = False
            break
    print(f"h. Đường chéo phụ giảm dần: {cheo_phu_giam}")

# --- CHƯƠNG TRÌNH CHÍNH ---

n_size = 3
x_value = 88
ma_tran_mau = [
    [1, 5, 3],
    [5, 4, 2],
    [3, 2, 6]
]

giai_cau_2(ma_tran_mau, n_size, x_value)

# %%
#3,4
#CÂU 3:

sinh_vien = {
    "SV01": {"ho_ten": "Nguyễn Văn A", "diem_tb": 8.5, "que_quan": "Hà Nội"},
    "SV02": {"ho_ten": "Trần Thị B", "diem_tb": 7.2, "que_quan": "Đà Nẵng"},
    "SV03": {"ho_ten": "Lê Văn C", "diem_tb": 9.0, "que_quan": "TP.HCM"}
}

# CÂU 4:
print("--- KẾT QUẢ XUẤT DICTIONARY (CÂU 4) ---")
for ma_sv, thong_tin in sinh_vien.items():
    print(f"Mã sinh viên: {ma_sv}")
    print(f"  + Họ tên: {thong_tin['ho_ten']}")
    print(f"  + Điểm trung bình: {thong_tin['diem_tb']}")
    print(f"  + Quê quán: {thong_tin['que_quan']}")
    print("-" * 30)
